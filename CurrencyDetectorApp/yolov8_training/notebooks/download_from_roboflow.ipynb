# %%
from roboflow import Roboflow
import os
import shutil

CURRENT_DIR = os.getcwd() # yolov8_training/notebooks
print("Current directory: {}".format(CURRENT_DIR))
BASE_DIR = os.path.dirname(CURRENT_DIR) # yolov8_training
print("Base directory: {}".format(BASE_DIR))
TARGET_DIR = os.path.join(BASE_DIR, "datasets", "raw_all_classes") # yolov8_training/datasets/raw_all_classes
print("Target directory: {}".format(TARGET_DIR))

roboflow = Roboflow(api_key="veRxzYnjgzvYsj12x9xZ")
project = roboflow.workspace().project("mkd-currency-recognition_v1")
dataset = project.version(6).download("yolov8")

if os.path.exists(TARGET_DIR):
    shutil.rmtree(TARGET_DIR)

shutil.move(dataset.location, TARGET_DIR)
print("✅ Dataset downloaded to:", TARGET_DIR)
# Out:
# Current directory: D:\CurrencyDetectorApp\yolov8_training\notebooks
# Base directory: D:\CurrencyDetectorApp\yolov8_training
# Target directory: D:\CurrencyDetectorApp\yolov8_training\datasets\raw_all_classes
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in mkd-currency-recognition_v1-6 to yolov8:: 100%|██████████| 25708/25708 [00:03<00:00, 7337.12it/s]
# Extracting Dataset Version Zip to mkd-currency-recognition_v1-6 in yolov8:: 100%|██████████| 1208/1208 [00:00<00:00, 1253.59it/s]
# ✅ Dataset downloaded to: D:\CurrencyDetectorApp\yolov8_training\datasets\raw_all_classes
